# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT AND BUSINESS CASE

# %% [markdown]
# <table>
#   <tr><td>
#     <img src="https://drive.google.com/uc?id=1yJKgmHrRFnBk987HJfeDrMcTEXtk0z7W"
#          alt="Fashion MNIST sprite"  width="1000">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1. Employee Retention Prediction
#   </td></tr>
# </table>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=10NJUOTWOBzp2MNkgcPpCF0fLtdoN_jKj)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1evbDHoW2t0emxkbQd8yevYFZ5woJKRPY)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Mk2H7VYfv6ijUS9XqEdBQV6_LaHiyvkJ)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# You will need to mount your drive using the following commands:
# For more information regarding mounting, please check this out: https://stackoverflow.com/questions/46986398/import-data-into-google-colaboratory

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# You have to include the full link to the csv file containing your dataset
employee_df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/DSforBiz_CaseStudies/Section3_HRDepartment/Human_Resources.csv')

# %%
employee_df #prints out the variable employee data file

# %%
#look at first 5 rows of data
employee_df.head(5)

# %%
#look at last 5 rows of data
employee_df.tail(5)

# %%
# info method, how many of the features are of int_64?
employee_df.info()

# %%
# decribe method, find the mean/average of the age column
employee_df["Age"].describe()
#employee_df.describe()

# %%
# 35 features in total, each contains 1470 data points

# %% [markdown]
# # TASK #3: VISUALIZE DATASET

# %%
# Let's replace 'Attritition' , 'overtime' , 'Over18' column with integers before performing any visualizations 
#Attirtion = no / yes
# overtime = no / yes, 1 or 0
# over18 can be changed from 1 and 0
#applying lambda function
employee_df['Attrition'] = employee_df['Attrition'].apply(lambda x:1 if x == 'Yes' else 0)
employee_df['OverTime'] = employee_df['OverTime'].apply(lambda x:1 if x == 'Yes' else 0)
employee_df['Over18'] = employee_df['Over18'].apply(lambda x:1 if x == 'Y' else 0)

# %%
employee_df

# %%
# Let's see if we have any missing data, luckily we don't!
# seaborn library heatmap, cbar false b/c binary 
sns.heatmap(employee_df.isnull(), yticklabels = False, cbar = False, cmap = 'Blues')

# %%
# Plot Histogram of data
employee_df.hist(bins = 30, figsize = (20, 20), color = 'r')
# Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy
# It makes sense to drop 'EmployeeCount' and 'Standardhours' since they do not change from one employee to the other
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4c0fa3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4c0ab630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4c05f898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4c015b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4c049d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bffefd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bfbd278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bf714a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bf71518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4beda9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4be8dc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bec1e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4be83128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4be36390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bdea5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bd9c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bd4fac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bd85d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bd39f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bcfb240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bcad4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bc60710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bc17978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bc49be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bbfde48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc5560bf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4c00cda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4be77c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bcce470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc4bafc198>]],
#       dtype=object)

# %%
# It makes sense to drop 'EmployeeCount' , 'Standardhours' and 'Over18' since they do not change from one employee to the other
# Let's drop 'EmployeeNumber' as well
# parameter inplace = True, changes value in memory for the dataframe
employee_df.drop(['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis = 1, inplace = True)

# %%
employee_df
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41          1  ...                       0                     5
# 1      49          0  ...                       1                     7
# 2      37          1  ...                       0                     0
# 3      33          0  ...                       3                     0
# 4      27          0  ...                       2                     2
# ...   ...        ...  ...                     ...                   ...
# 1465   36          0  ...                       0                     3
# 1466   39          0  ...                       1                     7
# 1467   27          0  ...                       0                     3
# 1468   49          0  ...                       0                     8
# 1469   34          0  ...                       1                     2
#
# [1470 rows x 31 columns]

# %%
# Let's see how many employees left the company! 
# separate data into two different dataframes, 
# Those who left and who stayed, then do analysis on the data sets
left_df = employee_df[employee_df['Attrition'] == 1]
stayed_df = employee_df[employee_df['Attrition'] == 0]

# %%
# Count the number of employees who stayed and left
# It seems that we are dealing with an imbalanced dataset 
print('Total = ', len(employee_df))
print('Number of employees that left = ', len(left_df))
print('Number of employees that stayed = ', len(stayed_df))
# why is there a 1., AFAIK, it makes it a float
print('% of employees who left =', 1. * len(left_df)/len(employee_df) * 100, '%')
print('% of employees who stayed =', 1. * (len(stayed_df)/len(employee_df)*100), '%')
# Out:
# Total =  1470
# Number of employees that left =  237
# Number of employees that stayed =  1233
# % of employees who left = 16.122448979591837 %
# % of employees who stayed = 83.87755102040816 %

# %%
left_df.describe()

#  Let's compare the mean and std of the employees who stayed and left
# Out:
#               Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  237.000000      237.0  ...               237.000000            237.000000
# mean    33.607595        1.0  ...                 1.945148              2.852321
# std      9.689350        0.0  ...                 3.153077              3.143349
# min     18.000000        1.0  ...                 0.000000              0.000000
# 25%     28.000000        1.0  ...                 0.000000              0.000000
# 50%     32.000000        1.0  ...                 1.000000              2.000000
# 75%     39.000000        1.0  ...                 2.000000              5.000000
# max     58.000000        1.0  ...                15.000000             14.000000
#
# [8 rows x 25 columns]

# %%
# look at those that stayed too
stayed_df.describe()
# 'age': mean age of the employees who stayed is higher compared to who left
# 'DailyRate': Rate of employees who stayed is higher
# 'DistanceFromHome': Employees who stayed live closer to home 
# 'EnvironmentSatisfaction' & 'JobSatisfaction': Employees who stayed are generally more satisifed with their jobs
# 'StockOptionLevel': Employees who stayed tend to have higher stock option level
# Out:
#                Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1233.000000     1233.0  ...              1233.000000           1233.000000
# mean     37.561233        0.0  ...                 2.234388              4.367397
# std       8.888360        0.0  ...                 3.234762              3.594116
# min      18.000000        0.0  ...                 0.000000              0.000000
# 25%      31.000000        0.0  ...                 0.000000              2.000000
# 50%      36.000000        0.0  ...                 1.000000              3.000000
# 75%      43.000000        0.0  ...                 3.000000              7.000000
# max      60.000000        0.0  ...                15.000000             17.000000
#
# [8 rows x 25 columns]

# %%
# Looking at the correlations with corr()
correlations = employee_df.corr()
# Data correlation is the way in which one set of data may correspond to another set
# Use heatmap to plot the different correlations
fig, ax = plt.subplots(figsize = (25,25))
sns.heatmap(correlations, annot = True)
# 0 to 1, 1 being better collorated

# %%
# plot age and attrition, is there a correlation?
plt.figure(figsize = [25,12])
sns.countplot(x = 'Age', hue = 'Attrition', data = employee_df)

# %%
# Job level is strongly correlated with total working hours
# Monthly income is strongly correlated with Job level
# Monthly income is strongly correlated with total working hours
# Age is stongly correlated with monthly income

# %%
# plot the countplot for job role, marital status, job involvement and job level.
plt.figure(figsize= [20, 20]) # create a new figure
plt.subplot(411) # (nrows, ncols, index)
# Show the counts of observations in each categorical bin using bars.
sns.countplot(x = 'JobRole', hue = 'Attrition', data = employee_df)
plt.subplot(412) 
sns.countplot(x = 'MaritalStatus', hue = 'Attrition', data = employee_df)
plt.subplot(413)
sns.countplot(x = 'JobInvolvement', hue = 'Attrition', data = employee_df)
plt.subplot(414)
sns.countplot(x = 'JobLevel', hue = 'Attrition', data = employee_df)

# %%
# Single employees tend to leave compared to married and divorced
# Sales Representitives tend to leave compared to any other job 
# Less involved employees tend to leave the company 
# Less experienced (low job level) tend to leave the company

# %%
# KDE (Kernel Density Estimate) is used for visualizing the Probability Density of a continuous variable.
# KDE describes the probability density at different values in a continuous variable.
# set figure dimensions
plt.figure(figsize= (12, 7))
# taking a look at the distribution of the distanceFromHome variable against attrition
# KDE Plot, plot univariate or bivariate distributions using kernel density estimation
sns.kdeplot(left_df['DistanceFromHome'], label = 'Employees who left', shade = True, color = 'r') 
sns.kdeplot(stayed_df['DistanceFromHome'], label = 'Employees who stayed', shade = True, color = 'b')
plt.legend(loc='upper right') # display missing legend
plt.xlabel('Distance From Home') # x-axis label
# Out:
# Text(0.5, 0, 'Distance From Home')

# %%
# as the distance increases from 10+, the employees who leave is higher than those that stay
# Seems that there is some correlation between the distance and the employees who stay or leave.

# %%
# Quiz
# Plot the same KDE plot for YearsWithCurrManager , and TotalWorkingYears
plt.figure(figsize= [12, 14]) # Set figure dimensions
plt.subplot(211) # (nrows, ncols, index)
sns.kdeplot(left_df['YearsWithCurrManager'], label = 'Employees who left', shade = True, color = 'r')
sns.kdeplot(stayed_df['YearsWithCurrManager'], label = 'Employees who stayed', shade = True, color = 'b')
plt.legend(loc='upper right') # display missing legend
plt.xlabel('Years With Current Manager') # x-axis label

plt.subplot(212)
sns.kdeplot(left_df['TotalWorkingYears'], label = 'Employees who left', shade = True, color = 'r') 
sns.kdeplot(stayed_df['TotalWorkingYears'], label = 'Employees who stayed', shade = True, color = 'b')
plt.legend(loc='upper right') # display missing legend
plt.xlabel('Total Working Years') # x-axis label
# Seems that if years with manager is low, people tend to leave, however, as the 
# years increases, those that stay supersedes those that leave. Beyond 5 years
# employees tend to stay
# In the case for total working years, look like between 0 and 7 years employees
# tend to leave. Beyond 7 years, employees tend to stay. 
# Note: The plot was more smooth than in the tutorial
# Out:
# Text(0.5, 0, 'Total Working Years')

# %%
# Last two graphs are Box to Plots Box Plot 
# Let's see the Gender vs. Monthly Income
sns.boxplot(x = 'MonthlyIncome', y = 'Gender', data = employee_df)

# Average is comparable between M and F. Pay equality here. Slight difference, 
# females get paid even more.

# %%
# Let's see the Job Role vs. Monthly Income
plt.figure(figsize = (15, 10)) # Data set large
sns.boxplot(x = 'MonthlyIncome', y = 'JobRole', data = employee_df)

# Employees who work as managers, tend to be paid more 17k, research directors 
# too. Research Scientist and Lab Tech is similar. Sales Rep, less, and HR have 
# a range but is averaged near RS, LT, and SR. Sales Execs, Manu Dir, and Health
# Reps are almost similar.

# %% [markdown]
# # TASK #4: CREATE TESTING AND TRAINING DATASET & PERFORM DATA CLEANING

# %%
# note that we dropped the target 'Atrittion'

# %% [markdown]
# # TASK #5: UNDERSTAND THE INTUITION BEHIND LOGISTIC REGRESSION CLASSIFIERS, ARTIFICIAL NEURAL NETWORKS, AND RANDOM FOREST CLASSIFIER

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=19DpnhFkfsNEDPlH1dkfdr1zO36vRcBit)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1J03xZf6OiYtGV3IgJBUURBWyScpvaAbU)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1WNsznVn7je5r9HGnSLLdABICxrIv2Mrs)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1bX5uGmy5vbYTlp7m4tw_V2kTNzAHpHLp)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1ztrMNehNYWMw6NwhOOC9BDBdnoNirpqZ)

# %% [markdown]
# # TASK #6: UNDERSTAND HOW TO ASSESS CLASSIFICATION MODELS

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1OZLbKm1AJSyvoBgfvlfcLIWZxLOvzOWq)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=11pNdVw4oWeNOWrkadrrxon7FU4qO5m6U)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Bk1xFW2tGBdwg-njOhw79MxtYBQnK-6x)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=19cXoBqSiqbEGNofnD603bz3xEAsX28hy)

# %% [markdown]
# # TASK #7: TRAIN AND EVALUATE A LOGISTIC REGRESSION CLASSIFIER

# %%
# Testing Set Performance

# %% [markdown]
# # TASK #8: TRAIN AND EVALUATE A RANDOM FOREST CLASSIFIER

# %%
# Testing Set Performance

# %% [markdown]
# # TASK #9: TRAIN AND EVALUATE A DEEP LEARNING MODEL

# %%
# oversampler = SMOTE(random_state=0)
# smote_train, smote_target = oversampler.fit_sample(X_train, y_train)
# epochs_hist = model.fit(smote_train, smote_target, epochs = 100, batch_size = 50)

# %%
# Testing Set Performance

# %% [markdown]
# # EXCELLENT JOB! YOU SHOULD BE PROUD OF YOUR NEWLY ACQUIRED SKILLS
